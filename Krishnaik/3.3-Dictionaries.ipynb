# %%
## Dictionaries

## they are unordered collectiond of items. they store data in key value
#  pairs. keys must be unique and immutable(key cannot be changed, includes
#  strings, numbers or tuples), while values can be any type

# %%
## Creating Dictionaries
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
student = { "name" : "Sasidhar", "age":"20", "grade" : 24 }
print(student)
print(type(student))
# Out:
# {'name': 'Krish', 'age': '20', 'grade': 24}
# <class 'dict'>

# %%
student = { "name" : "Sasidhar", "age":"20", "name" : 24 }
print(student)


## the latest occurence of the value to the key is considered, the old value will be dicsarded
# Out:
# {'name': 24, 'age': '20'}

# %%
## acessing dictionary elements

student = { "name" : "Sasidhar", "age":"20", "grade" : "A" }
print(student)
# Out:
# {'name': 'Sasidhar', 'age': '20', 'grade': 'A'}

# %%
## acessing dictionary elements

print(student['grade'])
print(student['age'])

## acessing using get() method

print(student.get('grade'))
print(student.get('last'))
print(student.get('last', "Not available"))
# Out:
# A
# 20
# A
# None
# Not available

# %%
## Modifying dictionary elements
## Dictionaries are mutable, so you can add, update, or delte elements(only values, but key needsa to be unique)

print(student)
# Out:
# {'name': 'Sasidhar', 'age': '20', 'grade': 'A'}

# %%
student["age"] = 33 ## Updated a key
print(student)
student["address"] = "India" # Added a new key and value
print(student)
# Out:
# {'name': 'Sasidhar', 'age': 33, 'grade': 'A'}
# {'name': 'Sasidhar', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade'] ## Delete the key and value pair

print(student)
# Out:
# {'name': 'Sasidhar', 'age': 33, 'address': 'India'}

# %%
## Dictionary methods

keys = student.keys() ## Get all the keys
print(keys)
values = student.values() ##Get all the values
print(values)

items = student.items() ## Get all key value pairs, list of tuples
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Sasidhar', 33, 'India'])
# dict_items([('name', 'Sasidhar'), ('age', 33), ('address', 'India')])

# %%
## shallow copy

student_copy = student
print(student)
print(student_copy)
# Out:
# {'name': 'Sasidhar', 'age': 33, 'address': 'India'}
# {'name': 'Sasidhar', 'age': 33, 'address': 'India'}

# %%
student["name"] = "Sasi1"
print(student)
print(student_copy)
# Out:
# {'name': 'Sasi1', 'age': 33, 'address': 'India'}
# {'name': 'Sasi1', 'age': 33, 'address': 'India'}

# %%
student_copy1 = student.copy() ### Shallow copy, creates another memory sepereatly
print(student_copy)
print(student_copy1)
print(student)
# Out:
# {'name': 'Sasi1', 'age': 33, 'address': 'India'}
# {'name': 'Sasi1', 'age': 33, 'address': 'India'}
# {'name': 'Sasi1', 'age': 33, 'address': 'India'}

# %%
student["name"] = "Sasi2"
print(student_copy)
print(student_copy1, "This is a Shallow copy")
print(student)
# Out:
# {'name': 'Sasi2', 'age': 33, 'address': 'India'}
# {'name': 'Sasi1', 'age': 33, 'address': 'India'} This is a Shallow copy
# {'name': 'Sasi2', 'age': 33, 'address': 'India'}

# %%
## Iterating over dictionaries
## You can used loops to iterate over dictionaries, keys, values, or items

## Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
## Iterate over values
for value in student.values():
    print(value)
# Out:
# Sasi2
# 33
# India

# %%
## iterate over key value pairs

for key,value in student.items():
    print(f"{key} : {value}")
# Out:
# name : Sasi2
# age : 33
# address : India

# %%
## Nested Dictionaries

students={
    "student1" : {"name" : "Sasi", "age" : 20},
    "student2" : {"name" : "Thor", "age" : 1500}
}
print(students)
# Out:
# {'student1': {'name': 'Sasi', 'age': 20}, 'student2': {'name': 'Thor', 'age': 1500}}

# %%
## acess nested dictionaries

print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Thor
# 1500

# %%
## iterating over nested dicxtionaries

for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Sasi', 'age': 20}
# name:Sasi
# age:20
# student2:{'name': 'Thor', 'age': 1500}
# name:Thor
# age:1500

# %%
## Dictionary comprehension

squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## conditional dictionay comprehension

evens={x:x**2 for x in range(10) if x%2 ==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical examples

## use a dictionary to counat thr frequency of enements in list

numbers=[1,2,2,3,3,3,4,4,4,4]

frequency = {}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge 2 dictionaries into one

dict1={"a":1, "b":2}
dict2={"b":3, "c":4}
merge_dict={**dict1,**dict2}
print(merge_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
