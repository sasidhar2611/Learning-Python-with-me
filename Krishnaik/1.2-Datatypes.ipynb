# %%
## Integers Example
age=35
type(age)
# Out:
# int

# %%
## floating point datatype
height=5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## string datatype example
name ="Sasidhar"
print(name)
print(type(name))
# Out:
# Sasidhar
# <class 'str'>

# %%
## boolean datatype 
is_ture = True
type(True)
# Out:
# bool

# %%
a = 10
b = 10

type(a == b)
# Out:
# bool

# %%
## common errors

result = "Hello" + str(5)
print(result)
# Out:
# Hello5
