# %%
## if statement
age=20

if age>=18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the elections

# %%
## else statement
## The else statement executes a block of code if the condition in the if statement if False.

age = 16

if age>=18:
    print("Youa re elegible to vote")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif statemnt
## the elsif statement allows you to check multiple statements. it stands for "else if"

age = 17

if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are a teenager

# %%
##nested conditional statements
## You can place one or more if elif and else statement inside another if, elif, else staemnt to create a nested conditional statements

## number even,odd,negative

num=int(input("Enter the numnber"))

if num>0:
    print("The number is positive")
    if num%2 == 0:
        print("The number is even")
    else:
        print("The number is odd")

elif num == 0:
    print("The number is zero")

else:
    print("The number is negative")
# Out:
# The number is positive
# The number is odd

# %%
## Practical example

## Determine if a year ia a leap year using nested condition stratement

year = int(input("Enter a Year in YYYY fromat: ")) 

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"The year {year} is a LEAP YEAR")
else:
    print(f"The year {year} is not a Leap Year")
# Out:
# The year 1700 is not a Leap Year

# %%
## Assignment
## Simple Calculator program - input, operations, 

num1 = float(input("Enter number 1: "))
num2 = float(input("Enter number 2: "))
operator = input("Enter the operation( +, -, *, / ): ")

if operator == '+':
    print(num1 + num2)
elif operator == '-':
    print(num1 - num2)
elif operator == '*':
    print(num1 * num2)
elif operator == '/':
    if num2 == 0:
        print("Error! Division by Zero")
    else:
        print(num1 / num2)
else:
    print("Invalid Operation")
# Out:
# 98.0

# %%
## Determine the ticket price based on age and whether the person is a student.

age = int(input("Enter your Age"))

if age <=5:
    print("You are a Child you don't need a ticket!")
elif age >6 and age <=21:
    print("You are a student. You a get a 50% discounted Ticket at $5")
else:
    print("You are an adult. Your tickect is $10")
# Out:
# You are a student. You a get a 50% discounted Ticket at $5
