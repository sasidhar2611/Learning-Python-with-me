# %%
## Lambda Function

# Lambda functions are small anonymous functions defined using the lambda keyword.
# They can have any number of arguments but only one expression.
# They are commonly used for short operations or as arguments to higher order functions

# %%
#Syntax
lambda arguments: expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition = lambda a,b: a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2==0:
        return True
    
even(24)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition1 = lambda x, y, z : x+y+z
addition1(12,13,14)
# Out:
# 39

# %%
##map() - it applies a function to all items in the list

number = [1,2,3,4,5,6]
def square(number):
    return number**2

square(2)
# Out:
# 4

# %%
list(map(lambda x:x**2, number))

## map is not initialised by itself, so list is used to make it initialised
# Out:
# [1, 4, 9, 16, 25, 36]
