# %%
## Arithematic operations

a = 10
b = 5

add_result = a+b # additon
sub_result = a-b #subtraction
mult_result = a*b #multipluication
div_result = a/b #division
floor_div_result = a//b #floor division
modulus_result = a%b #modulud operation

exponential_result = a**b #exponential operation


print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponential_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %%
## Comparison operators
## == Equal to
a=10
b=10

a==b
# Out:
# True

# %%
str1 = "Sasi"
str2 = "Sasi" 

str1 == str2
# Out:
# True

# %%
## Not equal to
str1 != str2
# Out:
# False

# %%
str3 = "Sasi"
str4 = "sasi"

str3 != str4
# Out:
# True

# %%
## Greater than

num1 = 45
num2 = 55

num1>num2
# Out:
# False

# %%
## greater then or equal to

number1 = 45
number2 = 45

number1>=number2
# Out:
# True

# %%
## less then or equal to

number1 = 45
number2 = 45

number1<=number2
# Out:
# True

# %% [markdown]
# ### Logical Operators

# %%
## And, Not, Nor
X = True
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
X = True
Y = False

result = X and Y
print(result)
# Out:
# False

# %%
## OR

X = True
Y = False

result = X or Y
print(result)
# Out:
# True

# %%
#Not operation

X = True
Y = False
not X
#not Y
# Out:
# False

# %%
## Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

#Performing arithmetic operations
addition = num1+num2
subtraction = num1-num2
multiplication = num1*num2
division = num1/num2
floor_division = num1//num2
modulus = num1%num2
exponentation = num1**num2


print("Sum: ",addition)
print("Difference: ",subtraction)
print("Product: ",multiplication)
print("Quotient: ",division)
print("Floor Quotient: ",floor_division)
print("Reminder: ",modulus)
print("Exponentation: ",exponentation)
# Out:
# Sum:  98.0
# Difference:  16.0
# Product:  2337.0
# Quotient:  1.3902439024390243
# Floor Quotient:  1.0
# Reminder:  16.0
# Exponentation:  9.791947641036585e+71
