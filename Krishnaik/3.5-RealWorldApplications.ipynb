# %%
## To Do List

to_do_list=["Buy groceries", "clean the house", "Pay bills"]

## Adding to do Task
to_do_list.append("Schedule meeting")
to_do_list.append("Go for a run")

## Removing a completed task
to_do_list.remove("clean the house")

## Checking if a task is in the list
if "Pay bills" in to_do_list:
    print("Hey dont forget to pay the bills")

print("To do list remaning")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Hey dont forget to pay the bills
# To do list remaning
# -Buy groceries
# -Pay bills
# -Schedule meeting
# -Go for a run

# %%
## Organizing Student Grades
grades = [85, 92, 78, 90, 88]

## Adding a new grade
grades.append(95)
print(grades)

## Calculating the average point
average_grade = sum(grades)/len(grades)    ## sum - adds all the grades,   len - tells how many elements are present like the count

## Finding the highest and lowest grades
highest_grade = max(grades)               ## max - gives maximum out of all the grades
lowest_grade = min(grades)                ## min - gives the minimum out of all the grades
print(f"Highest grade : {highest_grade}")
print(f"Lowest Grade : {lowest_grade}")
# Out:
# [85, 92, 78, 90, 88, 95]
# Highest grade : 95
# Lowest Grade : 78

# %%
## Managing an Inventory
inventory = ["apples", "bananas", "oranges", "grapes"]

# adding a new item
inventory.append("strawberries")

# Removing an item that is out of stock
inventory.remove("bananas")

# Checking if an item is in stock
item = "oranges"
if item in inventory:
    print(f"{item} are in Stock")
else:
    print(f"{item} are out of Stock")

# Printing the inventory

print("Inventory List")
for items in inventory:
    print(f"-{items}")
# Out:
# oranges are in Stock
# Inventory List
# -apples
# -oranges
# -grapes
# -strawberries

# %%
## Collecting user feedback
feedback = ["Great service", "Very satisfied", "Could be better", "Excellent experience"]

## Adding new feedback
feedback.append("Not happy with the service")

## Counting specific feedback
positivie_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())  ## .lower() converts the whole string into lowercase
print(f"Positive Feedback Count: {positivie_feedback_count}")

## Printing all the feedbacks
print("User feedback:")
for comment in feedback:
    print(f"-{comment}")
# Out:
# Positive Feedback Count: 2
# User feedback:
# -Great service
# -Very satisfied
# -Could be better
# -Excellent experience
# -Not happy with the service
