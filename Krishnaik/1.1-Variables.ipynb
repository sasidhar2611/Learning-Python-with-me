# %%
a = 100

# %%
##Declaring and assigning Variables

age = 32
height = 6.1
name = "Sasidhar"
is_student=True

##printing the variables
print("age : ",age)
print("height : ",height)
print("Name : ",name)
# Out:
# age :  32
# height :  6.1
# Name :  Sasidhar

# %%
##Naming convention
## Varibale names should be descriptive
## They must always start with a letter or an '_' and contain letters, numbers and underscore within that
## Variables names are case sensitive

## valid variable name

first_name="Sasidhar"
last_name="S V"

# %%
# invalid varibale names

#2age = 30
#first-name= "Sasidhar"
##@name= "Sasi"

# %%
# case sensitivity
name = "Sasidhar"
Name = "SASI"

# %%
## Unerstanding variable types
## Python id dyanamically typed, type fo varibale is dettermined at runtime
age=25 #integer
height=6.1#float
name = "Sasidhar" #string
is_student = True #boolean

print(type(name))
# Out:
# <class 'str'>

# %%
## Type Checking and conversion

type(height)
# Out:
# float

# %%
age = 25
print(type(age))

#type conversion

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "Sasidhar"
#int(name) gives error as name is not number to be converted to int

# %%
height = 5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic typing
## python allows the type of a varibale to change as the progtram executes
var = 10 #int
print(var, type(var))

var = "Hello"
print(var, type(var))

var = 3.45
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.45 <class 'float'>

# %%
## input

age = int(input("What is your age"))
print(age, type(age))
# Out:
# 20 <class 'int'>

# %%
## Simple Calculator

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum: ", sum)
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: ", quotient)
# Out:
# Sum:  98.0
# Difference:  -16.0
# Product:  2337.0
# Quotient:  0.7192982456140351
